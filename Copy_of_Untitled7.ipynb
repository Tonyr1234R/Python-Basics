# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonyr1234R/Python-Basics/blob/main/Copy_of_Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
iris=sns.load_dataset("iris")

# %%
sns.lineplot(data=iris,x="sepal_length",y="sepal_width",hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(data=iris,x="sepal_length",y="sepal_width",hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.jointplot(data=iris,x="sepal_length",y="sepal_width",hue="species")

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >

# %%
sns.pairplot(data=iris)
